# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
##how to read the pandas documnetation
import pandas as pd 
pd.__version__
# Out:
# '1.2.4'

# %%
pd?

# %%
pd??

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
pd.Series()
# Out:
# <ipython-input-10-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.Series
# Out:
# pandas.core.series.Series

# %%
data = pd.read_csv('titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.head(n = 3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.tail(n = 10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.shape
# Out:
# (891, 9)

# %%
Survived = titanic['survived']
print(Survived)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
print(type(Survived))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### how to conduct the pandas series

# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dell\anaconda3\lib\site-packages)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_data(df):
    # Univariate Analysis
    def univariate_analysis(df):
        univariate_summary = []
        for column in df.columns:
            column_summary = {
                'Column': column,
                'Data Type': df[column].dtype,
                'Unique Values': df[column].nunique(),
                'Missing Values': df[column].isnull().sum()
            }
            if df[column].dtype == 'object':
                column_summary['Mode'] = df[column].mode()[0]
                column_summary['Value Counts'] = df[column].value_counts().to_dict()
            else:
                column_summary.update({
                    'Mean': df[column].mean(),
                    'Median': df[column].median(),
                    'Std Dev': df[column].std(),
                    'Min': df[column].min(),
                    'Max': df[column].max(),
                    '25th Percentile': df[column].quantile(0.25),
                    '50th Percentile': df[column].quantile(0.5),
                    '75th Percentile': df[column].quantile(0.75)
                })
            univariate_summary.append(column_summary)

            # Plotting
            plt.figure(figsize=(10, 4))
            if df[column].dtype == 'object':
                sns.countplot(x=df[column], palette='viridis')
                plt.xticks(rotation=90)
            else:
                sns.histplot(df[column], kde=True, bins=30, palette='viridis')
            plt.title(f'Distribution of {column}')
            plt.show()
        
        return pd.DataFrame(univariate_summary)
    
    # Bivariate Analysis
    def bivariate_analysis(df):
        bivariate_summary = []
        for i, column1 in enumerate(df.columns):
            for j, column2 in enumerate(df.columns):
                if i >= j:
                    continue
                analysis = {
                    'Column 1': column1,
                    'Column 2': column2,
                }
                if df[column1].dtype == 'object' and df[column2].dtype == 'object':
                    analysis['Type'] = 'Categorical vs Categorical'
                    analysis['Crosstab'] = pd.crosstab(df[column1], df[column2]).to_dict()
                    sns.countplot(x=df[column1], hue=df[column2], palette='viridis')
                elif df[column1].dtype != 'object' and df[column2].dtype != 'object':
                    analysis['Type'] = 'Numerical vs Numerical'
                    analysis['Correlation'] = df[[column1, column2]].corr().iloc[0, 1]
                    sns.scatterplot(x=df[column1], y=df[column2], palette='viridis')
                else:
                    analysis['Type'] = 'Categorical vs Numerical'
                    if df[column1].dtype == 'object':
                        sns.boxplot(x=df[column1], y=df[column2], palette='viridis')
                    else:
                        sns.boxplot(x=df[column2], y=df[column1], palette='viridis')
                bivariate_summary.append(analysis)
                plt.title(f'Relationship between {column1} and {column2}')
                plt.show()
        
        return pd.DataFrame(bivariate_summary)
    
    # Perform analyses
    univariate_df = univariate_analysis(df)
    bivariate_df = bivariate_analysis(df)
    
    return univariate_df, bivariate_df

# Example usage:
# df = pd.read_csv('your_data.csv')
# univariate_summary, bivariate_summary = analyze_data(df)
# print(univariate_summary)
# print(bivariate_summary)

# %%
univariate_summary, bivariate_summary = analyze_data(df)

# %%
print(univariate_summary)
print(bivariate_summary)
# Out:
#      Column Data Type  Unique Values  Missing Values       Mean   Median  \
# 0  survived     int64              2               0   0.383838   0.0000
# 1    pclass     int64              3               0   2.308642   3.0000
# 2       sex    object              2               0        NaN      NaN
# 3       age   float64             88             177  29.699118  28.0000
# 4     sibsp     int64              7               0   0.523008   0.0000
# 5     parch     int64              7               0   0.381594   0.0000
# 6      fare   float64            248               0  32.204208  14.4542
# 7  embarked    object              3               2        NaN      NaN
# 8      deck    object              7             688        NaN      NaN
#
#      Std Dev   Min       Max  25th Percentile  50th Percentile  \
# 0   0.486592  0.00    1.0000           0.0000           0.0000
# 1   0.836071  1.00    3.0000           2.0000           3.0000
# ...
